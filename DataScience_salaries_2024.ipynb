# %% [markdown]
# # Loading and Inspecting the Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
datascience_salaries_2024 = pd.read_csv('DataScience_salaries_2024.csv')

# %%
datascience_salaries_2024
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
# Display the first few rows of the dataset
datascience_salaries_2024.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# ...

# %%
# Get a summary of the dataset
datascience_salaries_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
#Check for missing values
datascience_salaries_2024.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# # Descriptive Analysis

# %%
# What is the average, median, and mode of the salaries in the dataset?
average_salary = datascience_salaries_2024['salary'].mean()
median_salary = datascience_salaries_2024['salary'].median()
mode_salary = datascience_salaries_2024['salary'].mode()[0]
salary_range = (datascience_salaries_2024['salary'].min(),datascience_salaries_2024['salary'].max())
salary_std_dev = datascience_salaries_2024['salary'].std()

print("Average Salary:", average_salary)
print("Median Salary:", median_salary)
print("Mode Salary:", mode_salary)
print("Salary Range:", salary_range)
print("Salary Standard Deviation:", salary_std_dev)

# Unique job title
unique_job_titles = datascience_salaries_2024['job_title'].nunique()
print("Number of Unique Job Titles:", unique_job_titles)

# Top 10 Most common job title
top_job_titles = datascience_salaries_2024['job_title'].value_counts().head(10)
print("Top 10 Job Titles:\n", top_job_titles)
# Out:
# Average Salary: 165022.71896482006
# Median Salary: 142200.0
# Mode Salary: 150000
# Salary Range: (14000, 30400000)
# Salary Standard Deviation: 356235.42652234697
# Number of Unique Job Titles: 153
# Top 10 Job Titles:
#  job_title
# Data Engineer                     3162
# Data Scientist                    3015
# Data Analyst                      2189
# Machine Learning Engineer         1542
# Research Scientist                 475
# Analytics Engineer                 403
# Applied Scientist                  383
# Data Architect                     369
# Research Engineer                  276
# Business Intelligence Engineer     230
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(top_job_titles.index, top_job_titles.values, color='blue')

# Adding labels to the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')

# Add title and labels
plt.title('Top 10 Most Common Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Count')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.show()

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Distribution of salaries
sns.histplot(datascience_salaries_2024['salary'], kde=True)
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure that columns are properly named and stripped of any extra spaces
datascience_salaries_2024.columns = datascience_salaries_2024.columns.str.strip()

# Calculate the median salary for each job title and select the top 3
top_job_titles = datascience_salaries_2024.groupby('job_title')['salary'].median().nlargest(10).index

# Filter the DataFrame to include only these top job titles
filtered_data = datascience_salaries_2024[datascience_salaries_2024['job_title'].isin(top_job_titles)]

# Prepare data for the boxplot
salary_data = [filtered_data[filtered_data['job_title'] == title]['salary'] for title in top_job_titles]

# Plotting with Matplotlib
plt.figure(figsize=(10, 6))
plt.boxplot(salary_data, labels=top_job_titles)
plt.title('Salary by Job Title (Top 3)')
plt.xlabel('Job Title')
plt.ylabel('Salary')
plt.xticks(rotation=90)

# Add labels for median salary on top of each boxplot
medians = [data.median() for data in salary_data]
for i, median in enumerate(medians):
    plt.text(i + 1, median + 1000, f'{median:.0f}', ha='center', color='black')

plt.show()

# %%
print(datascience_salaries_2024.dtypes)
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# Drop non-numeric columns
datascience_salaries_2024 = datascience_salaries_2024.select_dtypes(include=[np.number])

# %%
# Correlation heatmap
sns.heatmap(datascience_salaries_2024.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
print(datascience_salaries_2024.columns)
# Out:
# Index(['work_year', 'salary', 'salary_in_usd', 'remote_ratio'], dtype='object')

# %%
# Salary by years of experience
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='experience_level', y='salary', data=datascience_salaries_2024)
plt.title('Salary vs Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.show()

# %%
print(datascience_salaries_2024.columns)
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure that columns are properly named and stripped of any extra spaces
datascience_salaries_2024.columns = datascience_salaries_2024.columns.str.strip()

# Convert columns to appropriate data types if needed
datascience_salaries_2024['company_location'] = datascience_salaries_2024['company_location'].astype(str)
datascience_salaries_2024['salary'] = datascience_salaries_2024['salary'].astype(float)

# Calculate average salary by location
average_salary_by_location = datascience_salaries_2024.groupby('company_location')['salary'].mean()

# Get the top 5 locations by average salary
top_5_locations = average_salary_by_location.nlargest(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(top_5_locations.index, top_5_locations.values, color='skyblue')

# Add labels to each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:,.0f}', 
             ha='center', va='bottom', fontsize=10)

plt.title('Top 5 Locations by Average Salary')
plt.xlabel('Location')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed for better readability
plt.show()
